# %%
wt='...'
mut='...'
wt_length=len(wt)
mut_length=len(mut)
distance=0
if wt_length!=mut_length:
    print("Hamming distance cannot be calculated")

for i in range (len(mut)):
        if mut[i]!=wt[i]:
            distance=distance+1 
        else:
            continue
print(distance)
