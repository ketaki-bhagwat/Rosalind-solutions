# %%
string='...'

rev=string[::-1]
print(rev)
revc=[]
for i in rev:
    if i=="T":
        r=i.replace("T","A")
    elif i=="G":
        r=i.replace("G","C")
    elif i=="C":
        r=i.replace("C","G")
    elif i=="A":
        r=i.replace("A","T")
    revc.append(r)
rev_complement="".join(revc)
print(rev_complement)
# Out:
# ...
# ...
