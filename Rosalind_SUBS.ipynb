# %%
import re

# %%
s='...'
t='ATCTGCGAT'
motif = f"(?=({re.escape(t)}))"
slength=len(s)
tlength=len(t)
if tlength>slength:
    print("motif larger than query")
for match in re.finditer(motif,s):
    print(match.start()+1,end=" ")
# Out:
# 63 91 110 126 241 271 319 345 390 434 485 492 525 570 577 615 703 769 921 928
